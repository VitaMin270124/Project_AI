# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Project_EmbeddedAI/test_code
# Out:
# /content/drive/MyDrive/Project_EmbeddedAI/test_code

# %%
# !python main.py
# Out:
# ./RescueNet/segmentation-validationset/val-org-img/11251.jpg
# ./RescueNet/segmentation-validationset/val-org-img/11122.jpg
# ./RescueNet/segmentation-validationset/val-org-img/10997.jpg
# ./RescueNet/segmentation-validationset/val-org-img/11005.jpg
# ./RescueNet/segmentation-validationset/val-org-img/10925.jpg
# ./RescueNet/segmentation-validationset/val-org-img/11437.jpg
# ./RescueNet/segmentation-validationset/val-org-img/12224.jpg
# ./RescueNet/segmentation-validationset/val-org-img/12045.jpg
# ./RescueNet/segmentation-validationset/val-org-img/11905.jpg
# ./RescueNet/segmentation-validationset/val-org-img/12214.jpg
# ./RescueNet/segmentation-validationset/val-org-img/11610.jpg
# ./RescueNet/segmentation-validationset/val-org-img/11420.jpg
# ./RescueNet/segmentation-validationset/val-org-img/11654.jpg
# ./RescueNet/segmentation-validationset/val-org-img/12298.jpg
# ./RescueNet/segmentation-validationset/val-org-img/12034.jpg
# ...
